# %% [markdown]
# ### Note: These predictions are based on totally data set used in this notebook the predicted terrorist attacks might be true or false depending on the patterns learned by machine.

# %% [markdown]
# # Import the data
# The very fist setp is to import the data in notebook that can be further used and get a glismpse of data to know how our data actually looks.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # visualizations
df = pd.read_csv("../input/globalterrorismdb_0718dist.csv", encoding = "ISO-8859-1", engine='python')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region   ...    addnotes scite1 scite2  scite3  \
# 0  Dominican Republic       2   ...         NaN    NaN    NaN     NaN
# 1              Mexico       1   ...         NaN    NaN    NaN     NaN
# 2         Philippines       5   ...         NaN    NaN    NaN     NaN
# 3              Greece       8   ...         NaN    NaN    NaN     NaN
# 4               Japan       4   ...         NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      PGIS        0         0        0       0      NaN
# 1      PGIS        0         1        1       1      NaN
# 2      PGIS       -9        -9        1       1      NaN
# 3      PGIS       -9        -9        1       1      NaN
# 4      PGIS       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# # Data cleaning
# Most of our data have NaN or 0's none of them are of our use, the next step is to clean our data and select only few columns from whole data that acually worth to us.

# %%
columns = ['iyear', 'imonth', 'iday', 'country_txt', 'city', 'latitude', 'longitude', 'success', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt']
df = df[columns]
df = df[(df[['iyear','imonth', 'iday']] != 0).all(axis=1)]
df.dropna()
# Out:
#         iyear  imonth  iday         country_txt                    city  \
# 0        1970       7     2  Dominican Republic           Santo Domingo
# 5        1970       1     1       United States                   Cairo
# 6        1970       1     2             Uruguay              Montevideo
# 7        1970       1     2       United States                 Oakland
# 8        1970       1     2       United States                 Madison
# 9        1970       1     3       United States                 Madison
# 10       1970       1     1       United States                 Baraboo
# 11       1970       1     6       United States                  Denver
# 12       1970       1     8               Italy                    Rome
# 13       1970       1     9       United States                 Detroit
# 14       1970       1     9       United States             Rio Piedras
# 17       1970       1    12       United States           New York City
# 18       1970       1    12       United States              Rio Grande
# 19       1970       1    13       United States                 Seattle
# 20       1970       1    14       United States               Champaign
# 21       1970       1    15             Uruguay              Montevideo
# 22       1970       1    19       United States                 Seattle
# 23       1970       1    19       United States                 Seattle
# 24       1970       1    19       United States             Jersey City
# 25       1970       1    20           Guatemala          Guatemala City
# 26       1970       1    21         Philippines             Quezon City
# 27       1970       1    22           Venezuela                 Caracas
# 28       1970       1    22       United States        South Sioux City
# 29       1970       1    25       United States              West Point
# 30       1970       1    25       United States           New York City
# 31       1970       1    26       United States              West Point
# 32       1970       1    26       United States           New York City
# 33       1970       1    27       United States                 Norwalk
# 34       1970       1    28  East Germany (GDR)                  Berlin
# 35       1970       1    28       United States                 Seattle
# ...       ...     ...   ...                 ...                     ...
# 181660   2017      12    30             Ukraine                 Kharkiv
# 181661   2017      12    28               India               Talacheru
# 181662   2017      12    30         Philippines               Tarragona
# 181663   2017      12    30               India           Koothuparamba
# 181664   2017      12    30      United Kingdom                 Belfast
# 181665   2017      12    30               India                Toylanka
# 181666   2017      12    30             Nigeria        Konduga district
# 181667   2017      12    30               Syria                 Harasta
# 181668   2017      12    31                Iraq                 Shurjah
# 181669   2017      12    30                Iraq                  Kirkuk
# 181670   2017      12    31                Iraq            Hawd al-Waqf
# 181671   2017      12    31                Iraq              Farhatiyah
# 181672   2017      12    31               India               Lethapora
# 181673   2017      12    31         Afghanistan               Jalalabad
# 181674   2017      12    31                Iraq                    Baaj
# 181675   2017      12    31             Somalia               Mogadishu
# 181676   2017      12    31         Afghanistan  Mohammad Agha district
# 181677   2017      12    31         Philippines                 Limpogo
# 181678   2017      12    30         Philippines          Pikit district
# 181679   2017      12    31                Iraq              Muqdadiyah
# 181680   2017      12    31             Somalia                   Wajid
# 181681   2017      12    31         Philippines           Shariff Aguak
# 181682   2017      12    31               Italy               Spinetoli
# 181683   2017      12    31         Afghanistan       Kohistan district
# 181684   2017      12    31               India                 Hungrum
# 181685   2017      12    31         Afghanistan                 Maymana
# 181686   2017      12    31             Somalia           Ceelka Geelow
# 181687   2017      12    31               Syria                  Jableh
# 181688   2017      12    31         Philippines                Kubentog
# 181689   2017      12    31               India                  Imphal
#
#          latitude   longitude  success                      attacktype1_txt  \
# 0       18.456792  -69.951164        1                        Assassination
# 5       37.005105  -89.176269        1                        Armed Assault
# 6      -34.891151  -56.187214        0                        Assassination
# 7       37.791927 -122.225906        1                    Bombing/Explosion
# 8       43.076592  -89.412488        1       Facility/Infrastructure Attack
# 9       43.072950  -89.386694        1       Facility/Infrastructure Attack
# 10      43.468500  -89.744299        0                    Bombing/Explosion
# 11      39.758968 -104.876305        1       Facility/Infrastructure Attack
# 12      41.890961   12.490069        1                            Hijacking
# 13      42.331685  -83.047924        1       Facility/Infrastructure Attack
# 14      18.386932  -66.061127        1       Facility/Infrastructure Attack
# 17      40.697132  -73.931351        1                    Bombing/Explosion
# 18      18.379998  -65.830948        1                    Bombing/Explosion
# 19      47.610786 -122.331306        1       Facility/Infrastructure Attack
# 20      40.116748  -88.239270        1       Facility/Infrastructure Attack
# 21     -34.891151  -56.187214        1                        Armed Assault
# 22      47.610786 -122.331306        1                    Bombing/Explosion
# 23      47.610786 -122.331306        0                    Bombing/Explosion
# 24      40.717892  -74.067467        1       Facility/Infrastructure Attack
# 25      14.622869  -90.529068        1                        Assassination
# 26      14.674280  121.057495        1                    Bombing/Explosion
# 27      10.482834  -66.962128        1          Hostage Taking (Kidnapping)
# 28      42.470310  -96.413949        1                    Bombing/Explosion
# 29      33.606510  -88.650419        1       Facility/Infrastructure Attack
# 30      40.697132  -73.931351        1                        Armed Assault
# 31      33.606510  -88.650419        1                    Bombing/Explosion
# 32      40.697132  -73.931351        1                        Armed Assault
# 33      41.241996  -82.615241        1       Facility/Infrastructure Attack
# 34      52.501530   13.401851        1       Facility/Infrastructure Attack
# 35      47.610786 -122.331306        1                    Bombing/Explosion
# ...           ...         ...      ...                                  ...
# 181660  49.993500   36.230383        1  Hostage Taking (Barricade Incident)
# 181661  17.001086   81.807490        1       Facility/Infrastructure Attack
# 181662   7.042777  126.449221        1                    Bombing/Explosion
# 181663  11.831902   75.565432        1                    Bombing/Explosion
# 181664  54.607712   -5.956210        1                        Armed Assault
# 181665  18.802725   81.497666        1       Facility/Infrastructure Attack
# 181666  11.492144   12.969724        1       Facility/Infrastructure Attack
# 181667  33.561504   36.368763        1                    Bombing/Explosion
# 181668  35.560376   44.524705        1                    Bombing/Explosion
# 181669  35.452110   44.375465        1                    Bombing/Explosion
# 181670  33.816111   44.783524        1                              Unknown
# 181671  34.031331   44.070106        1                    Bombing/Explosion
# 181672  33.966527   74.964225        1                        Armed Assault
# 181673  34.417122   70.449593        1                    Bombing/Explosion
# 181674  36.045059   41.716717        0                              Unknown
# 181675   2.059819   45.326115        1                    Bombing/Explosion
# 181676  34.217806   69.109316        1                    Bombing/Explosion
# 181677   6.983953  124.420664        1       Facility/Infrastructure Attack
# 181678   7.053143  124.619270        1                    Bombing/Explosion
# 181679  33.953167   44.921906        0                        Armed Assault
# 181680   3.810951   43.246506        1                    Bombing/Explosion
# 181681   6.862806  124.443649        1                    Bombing/Explosion
# 181682  42.888982   13.772795        1       Facility/Infrastructure Attack
# 181683  35.315467   64.815508        1                        Armed Assault
# 181684  25.180162   93.015788        1          Hostage Taking (Kidnapping)
# 181685  35.921051   64.774544        1                    Bombing/Explosion
# 181686   2.359673   45.385034        1                        Armed Assault
# 181687  35.407278   35.942679        1                    Bombing/Explosion
# 181688   6.900742  124.437908        1       Facility/Infrastructure Attack
# 181689  24.798346   93.940430        0                    Bombing/Explosion
#
#                          targtype1_txt  \
# 0          Private Citizens & Property
# 5                               Police
# 6                               Police
# 7                            Utilities
# 8                             Military
# 9                 Government (General)
# 10                            Military
# 11                            Military
# 12                 Airports & Aircraft
# 13                Government (General)
# 14                            Business
# 17             Educational Institution
# 18                            Business
# 19                            Business
# 20                              Police
# 21             Educational Institution
# 22             Educational Institution
# 23                            Military
# 24             Violent Political Party
# 25             Government (Diplomatic)
# 26             Government (Diplomatic)
# 27                            Business
# 28         Private Citizens & Property
# 29         Private Citizens & Property
# 30                              Police
# 31                Government (General)
# 32                              Police
# 33                Government (General)
# 34                              Police
# 35      Religious Figures/Institutions
# ...                                ...
# 181660            Government (General)
# 181661  Religious Figures/Institutions
# 181662                        Military
# 181663                          Police
# 181664     Private Citizens & Property
# 181665                        Business
# 181666     Private Citizens & Property
# 181667                        Military
# 181668                        Military
# 181669                        Business
# 181670                          Police
# 181671     Private Citizens & Property
# 181672                          Police
# 181673     Private Citizens & Property
# 181674                        Military
# 181675                        Military
# 181676                          Police
# 181677     Private Citizens & Property
# 181678                        Business
# 181679                        Military
# 181680                        Military
# 181681                          Police
# 181682     Private Citizens & Property
# 181683    Terrorists/Non-State Militia
# 181684            Government (General)
# 181685                        Business
# 181686                        Military
# 181687                        Military
# 181688     Private Citizens & Property
# 181689            Government (General)
#
#                                          targsubtype1_txt
# 0                                          Named Civilian
# 5         Police Building (headquarters, station, school)
# 6                         Police Security Forces/Officers
# 7                                             Electricity
# 8                     Military Recruiting Station/Academy
# 9                     Government Building/Facility/Office
# 10          Military Barracks/Base/Headquarters/Checkpost
# 11                    Military Recruiting Station/Academy
# 12                           Aircraft (not at an airport)
# 13                    Government Building/Facility/Office
# 14                                  Retail/Grocery/Bakery
# 17                 School/University/Educational Building
# 18                              Multinational Corporation
# 19                                  Retail/Grocery/Bakery
# 20        Police Building (headquarters, station, school)
# 21                 School/University/Educational Building
# 22                 School/University/Educational Building
# 23                    Military Recruiting Station/Academy
# 24                                  Party Office/Facility
# 25                                      Embassy/Consulate
# 26                                      Embassy/Consulate
# 27                                  Retail/Grocery/Bakery
# 28                              House/Apartment/Residence
# 29                              Race/Ethnicity Identified
# 30                        Police Security Forces/Officers
# 31                                   Judge/Attorney/Court
# 32         Police Patrol (including vehicles and convoys)
# 33                    Government Building/Facility/Office
# 34                        Police Security Forces/Officers
# 35                                       Place of Worship
# ...                                                   ...
# 181660                Government Building/Facility/Office
# 181661                                   Place of Worship
# 181662  Military Personnel (soldiers, troops, officers...
# 181663    Police Building (headquarters, station, school)
# 181664                       Unnamed Civilian/Unspecified
# 181665                                       Construction
# 181666                            Vehicles/Transportation
# 181667      Military Barracks/Base/Headquarters/Checkpost
# 181668                        Military Unit/Patrol/Convoy
# 181669                                Restaurant/Bar/Café
# 181670    Police Building (headquarters, station, school)
# 181671                       Unnamed Civilian/Unspecified
# 181672    Police Building (headquarters, station, school)
# 181673  Procession/Gathering (funeral, wedding, birthd...
# 181674                                       Paramilitary
# 181675                        Military Unit/Patrol/Convoy
# 181676     Police Patrol (including vehicles and convoys)
# 181677                           Village/City/Town/Suburb
# 181678                              Retail/Grocery/Bakery
# 181679      Military Barracks/Base/Headquarters/Checkpost
# 181680      Military Barracks/Base/Headquarters/Checkpost
# 181681     Police Patrol (including vehicles and convoys)
# 181682       Refugee (including Camps/IDP/Asylum Seekers)
# 181683                                  Non-State Militia
# 181684  Politician or Political Party Movement/Meeting...
# 181685                              Retail/Grocery/Bakery
# 181686                                Military Checkpoint
# 181687      Military Barracks/Base/Headquarters/Checkpost
# 181688                          House/Apartment/Residence
# 181689                Government Building/Facility/Office
#
# [165853 rows x 11 columns]

# %% [markdown]
# Our data looks pretty good after some cleaning. Isn't it?

# %% [markdown]
# # Data Exploration
# Let's try to explore our data before getting into machine learning stuff.

# %% [markdown]
# ### Attacks in few countries since 1970

# %%
fig = plt.figure(figsize=(15,10))
countries = df[['country_txt']].drop_duplicates()
countries.values.tolist()
countries = [country for country_list in countries.values.tolist() for country in country_list]
for country in countries[:30]:
    country_data = df.loc[df['country_txt']==country]
    country_data.groupby('iyear').success.sum().plot(label=country)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Top 10 countries who face the most terrorist atack since 1970

# %%
total_attacks_in_each_country = df.groupby('country_txt').count()
countries_who_faced_max_attacks =  total_attacks_in_each_country.sort_values('success', ascending=False)[:10].index
countries_who_faced_max_attacks.values.tolist()
print("Countries who faced most terrorist attacks since 1970 are: ")
for country in countries_who_faced_max_attacks:
    print(f"{country}")
# Out:
# Countries who faced most terrorist attacks since 1970 are:
# Iraq
# Pakistan
# Afghanistan
# India
# Colombia
# Philippines
# Peru
# El Salvador
# United Kingdom
# Turkey

# %% [markdown]
# ### Number of terrorist attack per year

# %%
fig = plt.figure(figsize=(15,10))
x = df['iyear'].unique()
y = df.groupby('iyear').count()['country_txt']
plt.plot(x, y)
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Number of Terrorist Activities Per Year')
plt.xticks(x, x, rotation='90') # x, label, rotation
plt.show()

# %% [markdown]
# # Model Trainning
# Let's dive into trainning our model. Most of the cases it is very obious to find out which algorithm best suits for mahcine learning. In some cases it becomes a little bit tough for us to decide which algorithm suits best, we are going to use random forest as our data have multiple types so best algorithm which suits best for our problem in my sight is random forest.
#
# Let's dive!!

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
features_columns = ['iyear', 'imonth', 'iday','latitude', 'longitude', 'success']
output_columns = ['iyear', 'imonth', 'iday', 'latitude', 'longitude']
cleaned_data = pd.DataFrame(df[features_columns]).fillna(0)
features = cleaned_data[features_columns]
target = cleaned_data[output_columns]
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 0)
forest_model = RandomForestRegressor(max_depth=2, random_state=0)
forest_model.fit(X_train,y_train)
melb_preds = forest_model.predict(X_test)
print(mean_absolute_error(y_test, melb_preds))
# Out:
# 10.763107930683725

# %% [markdown]
# We got the pretty bad results in accuracy terms. May be feature selection was not quite good enough or model selection can be optimised more.
